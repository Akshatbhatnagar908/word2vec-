# %%
import gensim
from gensim.models import word2vec
from gensim.models import KeyedVectors
from sklearn.metrics.pairwise import cosine_similarity

# %%
word_vectors = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz',binary=True)

# %%
import numpy as np

# %%
def odd_one_out(words):
    """Accepts a list of words and returns the odd word"""
    
    # Generate all word embeddings for the given list
    all_word_vectors = [word_vectors[w] for w in words]
    avg_vector = np.mean(all_word_vectors,axis=0)
    print(avg_vector.shape)
    
    #Iterate over every word and find similarity
    odd_one_out = None
    min_similarity = 1.0 #Very high value
    
    for w in words:
        sim = cosine_similarity([word_vectors[w]],[avg_vector])
        if sim < min_similarity:
            min_similarity = sim
            odd_one_out = w
    
        print("Similairy btw %s and avg vector is %.2f"%(w,sim))
            
    return odd_one_out

# %%
import pandas as pd
df = pd.read_csv("Test.csv")
print(df.head())
# Out:
#       Word1      Word2    Word3      Word4     Word5
# 0  elephant       lion    tiger       goat     snake
# 1       man  policeman  fireman    teacher   postman
# 2     plane       bird   rocket    balloon       cat
# 3     onion     celery  lettuce  pineapple    potato
# 4     India   football   hockey    cricket  swimming

# %%
sent1=df["Word1"]
sent2=df["Word2"]
sent3=df["Word3"]
sent4=df["Word4"]
sent5=df["Word5"]
sent7=odd_one_out(sent1),odd_one_out(sent2),odd_one_out(sent3),odd_one_out(sent4),odd_one_out(sent5)
sent6=pd.DataFrame(sent7)
sent6.to_csv("new_file.csv")
# Out:
# (300,)
# Similairy btw elephant and avg vector is 0.41
# Similairy btw man and avg vector is 0.37
# Similairy btw plane and avg vector is 0.43
# Similairy btw onion and avg vector is 0.38
# Similairy btw India and avg vector is 0.46
# Similairy btw who and avg vector is 0.21
# Similairy btw on and avg vector is 0.20
# Similairy btw India and avg vector is 0.46
# Similairy btw Dollar and avg vector is 0.31
# Similairy btw eat and avg vector is 0.37
# Similairy btw car and avg vector is 0.38
# Similairy btw Poland and avg vector is 0.32
# Similairy btw Lake and avg vector is 0.26
# Similairy btw Sun and avg vector is 0.33
# Similairy btw fox and avg vector is 0.41
# Similairy btw veil and avg vector is 0.33
# Similairy btw Physics and avg vector is 0.25
# Similairy btw Assassinate and avg vector is 0.38
# Similairy btw Hostel and avg vector is 0.31
# Similairy btw Earth and avg vector is 0.41
# (300,)
# Similairy btw lion and avg vector is 0.41
# Similairy btw policeman and avg vector is 0.38
# Similairy btw bird and avg vector is 0.44
# Similairy btw celery and avg vector is 0.39
# Similairy btw football and avg vector is 0.32
# Similairy btw why and avg vector is 0.31
# Similairy btw in and avg vector is 0.25
# Similairy btw Australia and avg vector is 0.25
# Similairy btw Rupees and avg vector is 0.34
# Similairy btw sleep and avg vector is 0.33
# Similairy btw scooter and avg vector is 0.34
# Similairy btw Russia and avg vector is 0.30
# Similairy btw Sea and avg vector is 0.34
# Similairy btw Moon and avg vector is 0.41
# Similairy btw wolf and avg vector is 0.45
# Similairy btw turban and avg vector is 0.38
# Similairy btw Chemistry and avg vector is 0.27
# Similairy btw Kill and avg vector is 0.27
# Similairy btw Hotel and avg vector is 0.28
# Similairy btw Mars and avg vector is 0.40
# (300,)
# Similairy btw tiger and avg vector is 0.41
# Similairy btw fireman and avg vector is 0.39
# Similairy btw rocket and avg vector is 0.38
# Similairy btw lettuce and avg vector is 0.41
# Similairy btw hockey and avg vector is 0.36
# Similairy btw what and avg vector is 0.32
# Similairy btw over and avg vector is 0.21
# Similairy btw Japan and avg vector is 0.26
# Similairy btw Euros and avg vector is 0.27
# Similairy btw drink and avg vector is 0.39
# Similairy btw bike and avg vector is 0.43
# Similairy btw England and avg vector is 0.35
# Similairy btw River and avg vector is 0.32
# Similairy btw Star and avg vector is 0.29
# Similairy btw jackal and avg vector is 0.35
# Similairy btw helmet and avg vector is 0.44
# Similairy btw Geography and avg vector is 0.28
# Similairy btw Kidnap and avg vector is 0.40
# Similairy btw Inn and avg vector is 0.31
# Similairy btw Neptune and avg vector is 0.27
# (300,)
# Similairy btw goat and avg vector is 0.43
# Similairy btw teacher and avg vector is 0.35
# Similairy btw balloon and avg vector is 0.37
# Similairy btw pineapple and avg vector is 0.38
# Similairy btw cricket and avg vector is 0.37
# Similairy btw where and avg vector is 0.28
# Similairy btw their and avg vector is 0.21
# Similairy btw Russia and avg vector is 0.28
# Similairy btw Cents and avg vector is 0.30
# Similairy btw think and avg vector is 0.29
# Similairy btw bicycle and avg vector is 0.39
# Similairy btw Rome and avg vector is 0.22
# Similairy btw Pool and avg vector is 0.30
# Similairy btw Mars and avg vector is 0.39
# Similairy btw mouse and avg vector is 0.31
# Similairy btw shirt and avg vector is 0.36
# Similairy btw Botany and avg vector is 0.35
# Similairy btw Stab and avg vector is 0.40
# Similairy btw Club and avg vector is 0.28
# Similairy btw Pluto and avg vector is 0.46
# (300,)
# Similairy btw snake and avg vector is 0.51
# Similairy btw postman and avg vector is 0.34
# Similairy btw cat and avg vector is 0.53
# Similairy btw potato and avg vector is 0.31
# Similairy btw swimming and avg vector is 0.37
# Similairy btw is and avg vector is 0.28
# Similairy btw was and avg vector is 0.29
# Similairy btw China and avg vector is 0.35
# Similairy btw Money and avg vector is 0.36
# Similairy btw dance and avg vector is 0.34
# Similairy btw ship and avg vector is 0.33
# Similairy btw Ukraine and avg vector is 0.36
# Similairy btw Pond and avg vector is 0.35
# Similairy btw Egypt and avg vector is 0.35
# Similairy btw panther and avg vector is 0.41
# Similairy btw hat and avg vector is 0.33
# Similairy btw Universe and avg vector is 0.37
# Similairy btw Murder and avg vector is 0.40
# Similairy btw Motel and avg vector is 0.34
# Similairy btw Sun and avg vector is 0.32
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
# C:\Users\akshat bhatnagar\AppData\Local\Temp\ipykernel_25676\620816441.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Similairy btw %s and avg vector is %.2f"%(w,sim))
